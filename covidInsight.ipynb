# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import requests

# %%
data = requests.get("https://api.covid19api.com/summary")

d=data.json()
pd.DataFrame(d["Countries"])
# pd.head()
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan           210           33594
# 1           Albania          AL         albania            68            3106
# 2           Algeria          DZ         algeria           469           17348
# 3           Andorra          AD         andorra             0             855
# 4            Angola          AO          angola             0             386
# ..              ...         ...             ...           ...             ...
# 181        Viet Nam          VN         vietnam           369             369
# 182  Western Sahara          EH  western-sahara             0              10
# 183           Yemen          YE           yemen            21            1318
# 184          Zambia          ZM          zambia             0            1895
# 185        Zimbabwe          ZW        zimbabwe            98             885
#
# ...

# %%
data = pd.DataFrame(d["Countries"])

# %%
data.describe
# Out:
# <bound method NDFrame.describe of             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan           210           33594
# 1           Albania          AL         albania            68            3106
# 2           Algeria          DZ         algeria           469           17348
# 3           Andorra          AD         andorra             0             855
# 4            Angola          AO          angola             0             386
# ..              ...         ...             ...           ...             ...
# 181        Viet Nam          VN         vietnam           369             369
# 182  Western Sahara          EH  western-sahara             0              10
# 183           Yemen          YE           yemen            21            1318
# 184          Zambia          ZM          zambia             0            1895
# 185        Zimbabwe          ZW        zimbabwe            98             885
#
# ...

# %%
data["Premium"]
# Out:
# 0      {}
# 1      {}
# 2      {}
# 3      {}
# 4      {}
#        ..
# 181    {}
# 182    {}
# 183    {}
# 184    {}
# 185    {}
# Name: Premium, Length: 186, dtype: object

# %%
# Relating the Variables

# %%
data.columns
# Out:
# Index(['Country', 'CountryCode', 'Slug', 'NewConfirmed', 'TotalConfirmed',
#        'NewDeaths', 'TotalDeaths', 'NewRecovered', 'TotalRecovered', 'Date',
#        'Premium'],
#       dtype='object')

# %%
sns.relplot(x="NewConfirmed",y="TotalDeaths", data=data)

# %%
sns.relplot(x="NewConfirmed",y="TotalConfirmed", hue="Country" ,data=data)

# %%
k=data.sort_values("TotalConfirmed",axis=0,ascending=False)
k.head(10)
# Out:
#                        Country CountryCode            Slug  NewConfirmed  \
# 177   United States of America          US   united-states         58601
# 23                      Brazil          BR          brazil         44571
# 76                       India          IN           india         24879
# 138         Russian Federation          RU          russia          6534
# 131                       Peru          PE            peru          3633
# 34                       Chile          CL           chile          2064
# 176             United Kingdom          GB  united-kingdom           832
# 109                     Mexico          MX          mexico          6995
# 156                      Spain          ES           spain           383
# 78   Iran, Islamic Republic of          IR            iran          2691
#
#      TotalConfirmed  NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 177         3054699          0       131480             0          936476
# ...

# %%
sortedData= k
sns.relplot(x="NewConfirmed",y="TotalConfirmed", hue="Country" ,data=sortedData.head(10))

# %%
medicalDataFetch=pd.read_csv("covidPlayground\Datasets\Health_Expenditure_SHA_03062020102745867 - Health_Expenditure_SHA_03062020102745867.csv")

medicalDataFetch.head(5)
# Out:
#       HF       Financing scheme     HC  \
# 0  HFTOT  All financing schemes  HCTOT
# 1  HFTOT  All financing schemes  HCTOT
# 2  HFTOT  All financing schemes  HCTOT
# 3  HFTOT  All financing schemes  HCTOT
# 4  HFTOT  All financing schemes  HCTOT
#
#                                         Function     HP       Provider  \
# 0  Current expenditure on health (all functions)  HPTOT  All providers
# 1  Current expenditure on health (all functions)  HPTOT  All providers
# 2  Current expenditure on health (all functions)  HPTOT  All providers
# 3  Current expenditure on health (all functions)  HPTOT  All providers
# 4  Current expenditure on health (all functions)  HPTOT  All providers
#
#   MEASURE                          Measure LOCATION  Country  ...  Year  \
# 0  PARPIB  Share of gross domestic product      DNK  Denmark  ...  2010
# 1  PARPIB  Share of gross domestic product      DNK  Denmark  ...  2011
# 2  PARPIB  Share of gross domestic product      DNK  Denmark  ...  2012
# ...
